# %%
import pandas as pd
data={
    "Name": ["Alice","Bob","Charlie"],
    "Age":[20,34,56],
    "City":["Indore","Newyork","Chicago"]
    }

# %%
df=pd.DataFrame(data) 
df
# Out:
#       Name  Age     City
# 0    Alice   20   Indore
# 1      Bob   34  Newyork
# 2  Charlie   56  Chicago

# %%
df[['Name','Age']] # Select Indiviual Columns
# Out:
#       Name  Age
# 0    Alice   20
# 1      Bob   34
# 2  Charlie   56

# %%
# Find Row detail of indexing 1 
# ! Work with Indexing
df.loc[1]
# Out:
# Name        Bob
# Age          34
# City    Newyork
# Name: 1, dtype: object

# %%
df.iloc[1]
# Out:
# Name        Bob
# Age          34
# City    Newyork
# Name: 1, dtype: object

# %%
# Show dataframe
df
# Out:
#       Name  Age     City
# 0    Alice   20   Indore
# 1      Bob   34  Newyork
# 2  Charlie   56  Chicago

# %%
# Change Indexing 0,1,2 to given index
df.index=['winner','first_runner_Up','second_runner_up']

# %%
df
# Out:
#                      Name  Age     City
# winner              Alice   20   Indore
# first_runner_Up       Bob   34  Newyork
# second_runner_up  Charlie   56  Chicago

# %%
df.iloc[1]
# select index 1 for show row 1
# Out:
# Name        Bob
# Age          34
# City    Newyork
# Name: first_runner_Up, dtype: object

# %%
df.loc['first_runner_Up']
# select label first_runner_Up for row 1
# Out:
# Name        Bob
# Age          34
# City    Newyork
# Name: first_runner_Up, dtype: object

# %%
# ! Python specific  
del df['City'] 
#  Delete City

# %%
# ! Pandas Method
df=df.drop(['Age'],axis=1)
# axis

# %%
df
# Out:
#                      Name
# winner              Alice
# first_runner_Up       Bob
# second_runner_up  Charlie

# %%
# ! Rename Col Name
new_col={
    'Name':'NAME',
}
df.rename(columns=new_col,inplace=True)

df
# Out:
#                      NAME
# winner              Alice
# first_runner_Up       Bob
# second_runner_up  Charlie

# %%
# ! Uppercase for Name Column
uppercase_value=df['NAME'].str.upper()
uppercase_value
# Out:
# winner                ALICE
# first_runner_Up         BOB
# second_runner_up    CHARLIE
# Name: NAME, dtype: object

# %%
df['NAME UPPER']=df['NAME'].str.upper()
df
# Out:
#                      NAME NAME UPPER
# winner              Alice      ALICE
# first_runner_Up       Bob        BOB
# second_runner_up  Charlie    CHARLIE

# %% [markdown]
# Performing Data Analysis Over Some Random Data

# %%
data=pd.read_csv('data.csv')
data
# Out:
#       Name   Age     City    Position
# 0    Divya  23.0   Indore     Manager
# 1    Rohan  24.0    Dewas   Developer
# 2  Charlie   NaN  NewYork     Analyst
# 3      Bob  20.0  Chicago    Designer
# 4    Alice  17.0  Phoenix  Consultant

# %%
# ! Handling Missing Value  
# 1.isnull() for check 
data.isnull().sum()
# Out:
# Name        0
# Age         1
# City        0
# Position    0
# dtype: int64

# %%
#!Checking Notnull data 
data.notnull().sum()
# Out:
# Name        5
# Age         4
# City        5
# Position    5
# dtype: int64

# %%
data.dropna(axis=1)
# Out:
#       Name     City    Position
# 0    Divya   Indore     Manager
# 1    Rohan    Dewas   Developer
# 2  Charlie  NewYork     Analyst
# 3      Bob  Chicago    Designer
# 4    Alice  Phoenix  Consultant

# %% [markdown]
# Instead of dropping just fill values with actual values

# %%
data.fillna(0,inplace=True)
data
# Out:
#       Name   Age     City    Position
# 0    Divya  23.0   Indore     Manager
# 1    Rohan  24.0    Dewas   Developer
# 2  Charlie   0.0  NewYork     Analyst
# 3      Bob  20.0  Chicago    Designer
# 4    Alice  17.0  Phoenix  Consultant

# %%
data
# Out:
#       Name   Age     City    Position
# 0    Divya  23.0   Indore     Manager
# 1    Rohan  24.0    Dewas   Developer
# 2  Charlie   0.0  NewYork     Analyst
# 3      Bob  20.0  Chicago    Designer
# 4    Alice  17.0  Phoenix  Consultant

# %%
data.fillna(data['Age'].mean(),inplace=True)
data
# Out:
#       Name   Age     City    Position
# 0    Divya  23.0   Indore     Manager
# 1    Rohan  24.0    Dewas   Developer
# 2  Charlie   0.0  NewYork     Analyst
# 3      Bob  20.0  Chicago    Designer
# 4    Alice  17.0  Phoenix  Consultant

# %%
# Statistical Data
data.describe()
# Out:
#              Age
# count   5.000000
# mean   16.800000
# std     9.782638
# min     0.000000
# 25%    17.000000
# 50%    20.000000
# 75%    23.000000
# max    24.000000

# %%
# Descriptive Statistics of the dataframe
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      5 non-null      object
#  1   Age       5 non-null      float64
#  2   City      5 non-null      object
#  3   Position  5 non-null      object
# dtypes: float64(1), object(3)
# memory usage: 292.0+ bytes

# %%
# 1st 2 data
data.head(2)
# Out:
#     Name   Age    City   Position
# 0  Divya  23.0  Indore    Manager
# 1  Rohan  24.0   Dewas  Developer

# %%
# last 2 data
data.tail(2)
# Out:
#     Name   Age     City    Position
# 3    Bob  20.0  Chicago    Designer
# 4  Alice  17.0  Phoenix  Consultant

# %%
! pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
# Load the CSV File data 
df=pd.read_csv("data.csv")
df
# Out:
#       Name   Age     City    Position
# 0    Divya  23.0   Indore     Manager
# 1    Rohan  24.0    Dewas   Developer
# 2  Charlie   NaN  NewYork     Analyst
# 3      Bob  20.0  Chicago    Designer
# 4    Alice  17.0  Phoenix  Consultant

# %%
# Select Particular Multiple Columns
df[["Name","Age"]]
# Out:
#       Name   Age
# 0    Divya  23.0
# 1    Rohan  24.0
# 2  Charlie   NaN
# 3      Bob  20.0
# 4    Alice  17.0

# %%
#  Selecting a single row with help of index 
df.loc[1]
# Out:
# Name            Rohan
# Age              24.0
# City            Dewas
# Position    Developer
# Name: 1, dtype: object

# %%
#  Selecting a single row With help of position
df.iloc[1]
# Out:
# Name            Rohan
# Age              24.0
# City            Dewas
# Position    Developer
# Name: 1, dtype: object

# %% [markdown]
# ## Setting Individual Column as a Index

# %%
# Change Index or Reindexing
# ! Selecting Index of the Dataframe to the 'Name' column
# ? inplace= True means Modify in Col
# df.set_index('Name',inplace=True)

# %%
df
# Out:
#       Name   Age     City    Position
# 0    Divya  23.0   Indore     Manager
# 1    Rohan  24.0    Dewas   Developer
# 2  Charlie   NaN  NewYork     Analyst
# 3      Bob  20.0  Chicago    Designer
# 4    Alice  17.0  Phoenix  Consultant

# %% [markdown]
# Setting New data as Index

# %%
df.index=['a','b','c','d','e']
df
# Out:
#       Name   Age     City    Position
# a    Divya  23.0   Indore     Manager
# b    Rohan  24.0    Dewas   Developer
# c  Charlie   NaN  NewYork     Analyst
# d      Bob  20.0  Chicago    Designer
# e    Alice  17.0  Phoenix  Consultant

# %%
# Give data on the basis of Labels
df.loc['a']   #! Labels
# Out:
# Name          Divya
# Age            23.0
# City         Indore
# Position    Manager
# Name: a, dtype: object

# %%
#  Give data on the basis of Index

df.iloc[1]  #! Position
# Out:
# Name            Rohan
# Age              24.0
# City            Dewas
# Position    Developer
# Name: b, dtype: object

# %% [markdown]
# Deliting any Specific Column

# %%
# ! Python specific Method
# del df['City']

# %%
df
# Out:
#       Name   Age     City    Position
# a    Divya  23.0   Indore     Manager
# b    Rohan  24.0    Dewas   Developer
# c  Charlie   NaN  NewYork     Analyst
# d      Bob  20.0  Chicago    Designer
# e    Alice  17.0  Phoenix  Consultant

# %% [markdown]
# Drop any Column

# %%
# ! Pandas Specifc Method
# Structure and Data will be delete
df.drop(['Age'],axis=1)
# Out:
#       Name     City    Position
# a    Divya   Indore     Manager
# b    Rohan    Dewas   Developer
# c  Charlie  NewYork     Analyst
# d      Bob  Chicago    Designer
# e    Alice  Phoenix  Consultant

# %% [markdown]
# ## Rename Column name

# %%
new_column={
    'Name':"NAME",
    'Age':"AGE"
}
# ! Rename columms named new_column and inplace= True means modify if only col is available
df.rename(columns=new_column,inplace=True)
df
# Out:
#       NAME   AGE     City    Position
# a    Divya  23.0   Indore     Manager
# b    Rohan  24.0    Dewas   Developer
# c  Charlie   NaN  NewYork     Analyst
# d      Bob  20.0  Chicago    Designer
# e    Alice  17.0  Phoenix  Consultant

# %%
# Convert all Name in Upper case
# df["NAME"]=df['NAME'].str.upper()
df
# Out:
#       NAME   AGE     City    Position
# a    Divya  23.0   Indore     Manager
# b    Rohan  24.0    Dewas   Developer
# c  Charlie   NaN  NewYork     Analyst
# d      Bob  20.0  Chicago    Designer
# e    Alice  17.0  Phoenix  Consultant

# %%
# Store Name Uppercase in different Column
df["NAME_Upper"]=df['NAME'].str.upper()
df
# Out:
#       NAME   AGE     City    Position NAME_Upper
# a    Divya  23.0   Indore     Manager      DIVYA
# b    Rohan  24.0    Dewas   Developer      ROHAN
# c  Charlie   NaN  NewYork     Analyst    CHARLIE
# d      Bob  20.0  Chicago    Designer        BOB
# e    Alice  17.0  Phoenix  Consultant      ALICE

# %% [markdown]
# ## Handles Missing Value

# %%
df.isnull().sum()
# Out:
# NAME          0
# AGE           1
# City          0
# Position      0
# NAME_Upper    0
# dtype: int64

# %% [markdown]
# Delete or Drop row with null values

# %%
# Delete data In which value is missing
# df.dropna()

# %% [markdown]
# Delete or Drop Columns which has null Values

# %%
# ! Age Col is deleted because it have null values
# df.dropna(axis=1)

# %% [markdown]
# Replace a Null value with any value

# %%
# Fill null valye by mean of the Age value
df.fillna(df['AGE'].mean(),inplace=True)
df
# Out:
#       NAME   AGE     City    Position NAME_Upper
# a    Divya  23.0   Indore     Manager      DIVYA
# b    Rohan  24.0    Dewas   Developer      ROHAN
# c  Charlie  21.0  NewYork     Analyst    CHARLIE
# d      Bob  20.0  Chicago    Designer        BOB
# e    Alice  17.0  Phoenix  Consultant      ALICE

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, a to e
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   NAME        5 non-null      object
#  1   AGE         5 non-null      float64
#  2   City        5 non-null      object
#  3   Position    5 non-null      object
#  4   NAME_Upper  5 non-null      object
# dtypes: float64(1), object(4)
# memory usage: 412.0+ bytes

# %%
df.describe()
# Out:
#              AGE
# count   5.000000
# mean   21.000000
# std     2.738613
# min    17.000000
# 25%    20.000000
# 50%    21.000000
# 75%    23.000000
# max    24.000000
