# %%
import pandas as pd
data={
    "Name": ["Alice","Bob","Charlie"],
    "Age":[20,34,56],
    "City":["Indore","Newyork","Chicago"]
    }

# %%
df=pd.DataFrame(data) 
df
# Out:
#       Name  Age     City
# 0    Alice   20   Indore
# 1      Bob   34  Newyork
# 2  Charlie   56  Chicago

# %%
df[['Name','Age']] # Select Indiviual Columns
# Out:
#       Name  Age
# 0    Alice   20
# 1      Bob   34
# 2  Charlie   56

# %%
# Find Row detail of indexing 1 
# ! Work with Indexing
df.loc[1]
# Out:
# Name        Bob
# Age          34
# City    Newyork
# Name: 1, dtype: object

# %%
df.iloc[1]
# Out:
# Name        Bob
# Age          34
# City    Newyork
# Name: 1, dtype: object

# %%
# Show dataframe
df
# Out:
#       Name  Age     City
# 0    Alice   20   Indore
# 1      Bob   34  Newyork
# 2  Charlie   56  Chicago

# %%
# Change Indexing 0,1,2 to given index
df.index=['winner','first_runner_Up','second_runner_up']

# %%
df
# Out:
#                      Name  Age     City
# winner              Alice   20   Indore
# first_runner_Up       Bob   34  Newyork
# second_runner_up  Charlie   56  Chicago

# %%
df.iloc[1]
# select index 1 for show row 1
# Out:
# Name        Bob
# Age          34
# City    Newyork
# Name: first_runner_Up, dtype: object

# %%
df.loc['first_runner_Up']
# select label first_runner_Up for row 1
# Out:
# Name        Bob
# Age          34
# City    Newyork
# Name: first_runner_Up, dtype: object

# %%
# ! Python specific  
del df['City'] 
#  Delete City

# %%
# ! Pandas Method
df=df.drop(['Age'],axis=1)
# axis

# %%
df
# Out:
#                      NAME NAME UPPER
# winner              Alice      ALICE
# first_runner_Up       Bob        BOB
# second_runner_up  Charlie    CHARLIE

# %%
# ! Rename Col Name
new_col={
    'Name':'NAME',
}
df.rename(columns=new_col,inplace=True)

df
# Out:
#                      NAME
# winner              Alice
# first_runner_Up       Bob
# second_runner_up  Charlie

# %%
# ! Uppercase for Name Column
uppercase_value=df['NAME'].str.upper()
uppercase_value
# Out:
# winner                ALICE
# first_runner_Up         BOB
# second_runner_up    CHARLIE
# Name: NAME, dtype: object

# %%
df['NAME UPPER']=df['NAME'].str.upper()
df
# Out:
#                      NAME NAME UPPER
# winner              Alice      ALICE
# first_runner_Up       Bob        BOB
# second_runner_up  Charlie    CHARLIE
