# %%
! pip install pandas
# Out:
# Requirement already satisfied: pandas in C:\Users\Divya Kumawat\AppData\Local\Programs\Python\Python313\Lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in C:\Users\Divya Kumawat\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas) (2.2.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\Divya Kumawat\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in C:\Users\Divya Kumawat\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\Divya Kumawat\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in C:\Users\Divya Kumawat\AppData\Local\Programs\Python\Python313\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
data={
    "Name": ["Alice","Bob","Charlie"],
    "Age":[20,34,56],
    "City":["Indore","Newyork","Chicago"]
    }

# %%
df=pd.DataFrame(data) 
df
# Out:
#       Name  Age     City
# 0    Alice   20   Indore
# 1      Bob   34  Newyork
# 2  Charlie   56  Chicago

# %%
df[['Name','Age']] # Select Indiviual Columns
# Out:
#       Name  Age
# 0    Alice   20
# 1      Bob   34
# 2  Charlie   56

# %%
# Find Row detail of indexing 1 
# ! Work with Indexing
df.loc[1]
# Out:
# Name        Bob
# Age          34
# City    Newyork
# Name: 1, dtype: object

# %%
df.iloc[1]
# Out:
# Name        Bob
# Age          34
# City    Newyork
# Name: 1, dtype: object

# %%
# Show dataframe
df
# Out:
#       Name  Age     City
# 0    Alice   20   Indore
# 1      Bob   34  Newyork
# 2  Charlie   56  Chicago

# %%
# Change Indexing 0,1,2 to given index
df.index=['winner','first_runner_Up','second_runner_up']

# %%
df
# Out:
#                      Name  Age     City
# winner              Alice   20   Indore
# first_runner_Up       Bob   34  Newyork
# second_runner_up  Charlie   56  Chicago

# %%
df.iloc[1]
# select index 1 for show row 1
# Out:
# Name        Bob
# Age          34
# City    Newyork
# Name: first_runner_Up, dtype: object

# %%
df.loc['first_runner_Up']
# select label first_runner_Up for row 1
# Out:
# Age          34
# City    Newyork
# Name: first_runner_Up, dtype: object

# %%
del df['City'] 
#  Delete City
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Divya Kumawat\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'City'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 del df['City']
#
# File c:\Users\Divya Kumawat\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:4506, in NDFrame.__delitem__(self, key)
#    4501             deleted = True
#    4502 if not deleted:
#    4503     # If the above loop ran and didn't delete anything because
#    4504     # there was no match, this call should raise the appropriate
#    4505     # exception:
# -> 4506     loc = self.axes[-1].get_loc(key)
#    4507     self._mgr = self._mgr.idelete(loc)
#    4509 # delete from the caches
#
# File c:\Users\Divya Kumawat\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'City'

# %%
df=df.drop(['Age'],axis=1)

# %%
df
# Out:
#                      Name
# winner              Alice
# first_runner_Up       Bob
# second_runner_up  Charlie
