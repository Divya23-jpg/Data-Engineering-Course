# %%
import pandas as pd

# %%
data={
    "name":['Xavier','Ann','Jana','Robin','Amal','Noori','Yuan'],
    "city":['Mexico City','Tornoto','NewYork','Manchestor'],
    "age":[],
    'py_score':[]
}
row_label=[101,102,103,104,105,106,107]

# %%
df=pd.Dataframe(data,index=row_label)
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 df=pd.Dataframe(data,index=row_label)
#       2 df
#
# AttributeError: module 'pandas' has no attribute 'Dataframe'

# %%
df.loc[101:103]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df.loc[101:103]
#
# NameError: name 'df' is not defined

# %%
df['Java-score']=[90.4,90,23,87,67,56,44]

# %%
tem_c = [9.0, 7.34, 8,9.0, 7.34, 8,9.0, 7.34, 8,9.0, 7.34, 8,9.0, 7.34, 8,9.0, 7.34, 8,9.0, 7.34, 8,9.0, 7.34, 8]
tem_c
# Out:
# [9.0,
#  7.34,
#  8,
#  9.0,
#  7.34,
#  8,
#  9.0,
#  7.34,
#  8,
#  9.0,
#  7.34,
#  8,
#  9.0,
#  7.34,
#  8,
#  9.0,
#  7.34,
#  8,
#  9.0,
#  7.34,
#  8,
#  9.0,
#  7.34,
#  8]

# %%
dt=pd.date_range(start='2019-10-27 00:00:00',periods=24,freq='h')
dt
# Out:
# DatetimeIndex(['2019-10-27 00:00:00', '2019-10-27 01:00:00',
#                '2019-10-27 02:00:00', '2019-10-27 03:00:00',
#                '2019-10-27 04:00:00', '2019-10-27 05:00:00',
#                '2019-10-27 06:00:00', '2019-10-27 07:00:00',
#                '2019-10-27 08:00:00', '2019-10-27 09:00:00',
#                '2019-10-27 10:00:00', '2019-10-27 11:00:00',
#                '2019-10-27 12:00:00', '2019-10-27 13:00:00',
#                '2019-10-27 14:00:00', '2019-10-27 15:00:00',
#                '2019-10-27 16:00:00', '2019-10-27 17:00:00',
#                '2019-10-27 18:00:00', '2019-10-27 19:00:00',
#                '2019-10-27 20:00:00', '2019-10-27 21:00:00',
#                '2019-10-27 22:00:00', '2019-10-27 23:00:00'],
#               dtype='datetime64[ns]', freq='h')

# %%
df=pd.DataFrame(tem_c,index=dt,columns=['Temperature'])
df
# Out:
#                      Temperature
# 2019-10-27 00:00:00         9.00
# 2019-10-27 01:00:00         7.34
# 2019-10-27 02:00:00         8.00
# 2019-10-27 03:00:00         9.00
# 2019-10-27 04:00:00         7.34
# 2019-10-27 05:00:00         8.00
# 2019-10-27 06:00:00         9.00
# 2019-10-27 07:00:00         7.34
# 2019-10-27 08:00:00         8.00
# 2019-10-27 09:00:00         9.00
# 2019-10-27 10:00:00         7.34
# 2019-10-27 11:00:00         8.00
# 2019-10-27 12:00:00         9.00
# 2019-10-27 13:00:00         7.34
# 2019-10-27 14:00:00         8.00
# 2019-10-27 15:00:00         9.00
# 2019-10-27 16:00:00         7.34
# 2019-10-27 17:00:00         8.00
# 2019-10-27 18:00:00         9.00
# 2019-10-27 19:00:00         7.34
# 2019-10-27 20:00:00         8.00
# 2019-10-27 21:00:00         9.00
# 2019-10-27 22:00:00         7.34
# 2019-10-27 23:00:00         8.00

# %%
df['2019-10-27 10:00:00':'2019-10-27 12:00:00']
# Out:
#                      Temperature
# 2019-10-27 10:00:00         7.34
# 2019-10-27 11:00:00         8.00
# 2019-10-27 12:00:00         9.00

# %%
df.resample('h')

# %%
df.max()
# Out:
# Temperature    9.0
# dtype: float64

# %%
df.min()
# Out:
# Temperature    7.34
# dtype: float64

# %%
df.mean()
# Out:
# Temperature    8.113333
# dtype: float64

# %%
import matplotlib.pyplot as plt
df.plot()
# Out:
# <Axes: >
